# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import model_selection
import matplotlib.pyplot as plt
import torch
import scipy.stats as stats
import torch.nn as nn

# %%
here = np.load('lasso.npy', allow_pickle=True)
here.shape
# Out:
# (1494, 10)

# %%
# Lets grab our data from the pca transformation
X_numpy = np.load('pca_transformed_data_v1.npy', allow_pickle=True)
y_numpy = np.load('label.npy', allow_pickle=True)

# %%
X = torch.from_numpy(X_numpy.astype(np.float32)).squeeze()
y = torch.from_numpy(y_numpy.astype(np.float32))

# %%
#lets split our data
X_train, X_test, y_train, y_test = sklearn.model_selection.train_test_split(X, y, test_size=0.2,
                                                                           random_state= 51)

# %%
#send the data into gpu
device = 'mps' if torch.backends.mps.is_available() else 'cpu'
X_train,X_test, y_train,y_test = X_train.to(device), X_test.to(device), y_train.to(device), y_test.to(device)

# %%
# lets create a model for hyperparameter tuning
class NeuralNetworkWithHyper(nn.Module):
    def __init__(self,hidden_layers, num_hidden_units, input_size=18):
        super().__init__()
        self.input_size = input_size
        self.hidden_layers = hidden_layers
        self.num_hidden_units = num_hidden_units
        
        # Create a list to hold the layers
        self.layers = nn.ModuleList()
        
        #add the input layer
        self.layers.append(nn.Linear(input_size, num_hidden_units))
        self.layers.append(nn.ReLU())
       
        #add hidden layers
        for i in range(hidden_layers - 1):
            self.layers.append(nn.Linear(num_hidden_units, num_hidden_units))
            self.layers.append(nn.ReLU())
        #add the output layer
        self.layers.append(nn.Linear(num_hidden_units, 1))
        
        #add forward function
    def forward(self, x):
        for layer in self.layers:
            x = layer(x)
        return x

# %% [markdown]
# ### Study #1 Neural Network

# %%
#Lets set our loss function and optimizer
import optuna

def objective(trial):
    
    #define the search space
    learning_rate = trial.suggest_float("learning_rate", 1e-4, 1e-3)
    hidden_layers = trial.suggest_int("hidden_layers", 1, 2)
    num_hidden_units = trial.suggest_int("num_hidden_units", 26, 46)
    epoch_count = trial.suggest_int("epoch_count", 9000, 12000)
    weight_decay = trial.suggest_float("weight_decay", 1e-4, 1e-3)
    
    #create the model
    model = NeuralNetworkWithHyper(hidden_layers, 
                                   num_hidden_units 
                                   ).to('mps')
    optimizer = torch.optim.SGD(model.parameters(), learning_rate, weight_decay)
    loss_fn = torch.nn.L1Loss()
    
    #testing loop
    for epoch in range(epoch_count):
        #convert into train
        model.train()

        #fit data
        train_pred = model(X_train)

        #calculate loss
        train_loss = loss_fn(train_pred, y_train)


        #zero gradients
        optimizer.zero_grad()

        #back propagation
        train_loss.backward()

        #gradient descent
        optimizer.step()

        #testing
        model.eval()
        with torch.inference_mode():
            test_pred = model(X_test)
            test_loss = loss_fn(test_pred, y_test)
            spear_pred = test_pred.to('cpu')
            
    #spearman correlation coefficient       
    validation_metric = stats.spearmanr(y_test.to('cpu'), spear_pred).statistic
    
    #save model weights
    trial.set_user_attr('model_weights', model.state_dict())
    
    return validation_metric

#Create an Optuna Study
study = optuna.create_study(direction='maximize')

#Perform hyperparameter optimization
study.optimize(objective, n_trials=100)

#Print best spearman correlation coefficient
best_validation_metric = study.best_value
# Out:
# [I 2023-11-09 11:42:26,658] A new study created in memory with name: no-name-a48ce8f0-568f-4599-b3dd-8e905ecea162
# [I 2023-11-09 11:43:09,675] Trial 0 finished with value: 0.20064380379922508 and parameters: {'learning_rate': 0.0006320056287082589, 'hidden_layers': 2, 'num_hidden_units': 32, 'epoch_count': 9912, 'weight_decay': 0.000728828372857686}. Best is trial 0 with value: 0.20064380379922508.
# [I 2023-11-09 11:43:51,389] Trial 1 finished with value: 0.23450287357228772 and parameters: {'learning_rate': 0.0008314739688211142, 'hidden_layers': 2, 'num_hidden_units': 41, 'epoch_count': 9575, 'weight_decay': 0.00014672286486376343}. Best is trial 1 with value: 0.23450287357228772.
# [I 2023-11-09 11:44:44,729] Trial 2 finished with value: 0.21946230419124352 and parameters: {'learning_rate': 0.0006654309421044862, 'hidden_layers': 2, 'num_hidden_units': 34, 'epoch_count': 11597, 'weight_decay': 0.000312678003760284}. Best is trial 1 with value: 0.23450287357228772.
# [I 2023-11-09 11:45:27,571] Trial 3 finished with value: 0.20722302879255092 and parameters: {'learning_rate': 0.0007825825413033565, 'hidden_layers': 2, 'num_hidden_units': 40, 'epoch_count': 9847, 'weight_decay': 0.00044818066870279925}. Best is trial 1 with value: 0.23450287357228772.
# [I 2023-11-09 11:45:53,422] Trial 4 finished with value: 0.14038747642099345 and parameters: {'learning_rate': 0.00014924658042932717, 'hidden_layers': 1, 'num_hidden_units': 40, 'epoch_count': 11173, 'weight_decay': 0.00026988887803393205}. Best is trial 1 with value: 0.23450287357228772.
# [I 2023-11-09 11:46:43,389] Trial 5 finished with value: 0.23703413897605202 and parameters: {'learning_rate': 0.0008224617076859043, 'hidden_layers': 2, 'num_hidden_units': 33, 'epoch_count': 10738, 'weight_decay': 0.0006493432131154062}. Best is trial 5 with value: 0.23703413897605202.
# [I 2023-11-09 11:47:40,729] Trial 6 finished with value: 0.1623529432899806 and parameters: {'learning_rate': 0.0008291134377329368, 'hidden_layers': 2, 'num_hidden_units': 35, 'epoch_count': 10048, 'weight_decay': 0.0002071326278004696}. Best is trial 5 with value: 0.23703413897605202.
# [I 2023-11-09 11:48:02,401] Trial 7 finished with value: 0.18064328304574317 and parameters: {'learning_rate': 0.0002143027802219069, 'hidden_layers': 1, 'num_hidden_units': 29, 'epoch_count': 9224, 'weight_decay': 0.000887641854005763}. Best is trial 5 with value: 0.23703413897605202.
# [I 2023-11-09 11:48:28,536] Trial 8 finished with value: 0.24725302598250534 and parameters: {'learning_rate': 0.0006023848724727537, 'hidden_layers': 1, 'num_hidden_units': 42, 'epoch_count': 11103, 'weight_decay': 0.0009931875585096755}. Best is trial 8 with value: 0.24725302598250534.
# [I 2023-11-09 11:49:29,610] Trial 9 finished with value: 0.18096381572256995 and parameters: {'learning_rate': 0.000792191316861785, 'hidden_layers': 2, 'num_hidden_units': 39, 'epoch_count': 11184, 'weight_decay': 0.0007653639028175739}. Best is trial 8 with value: 0.24725302598250534.
# [I 2023-11-09 11:49:57,423] Trial 10 finished with value: 0.23548871356992296 and parameters: {'learning_rate': 0.00043252649601736273, 'hidden_layers': 1, 'num_hidden_units': 44, 'epoch_count': 11983, 'weight_decay': 0.0009740134434226405}. Best is trial 8 with value: 0.24725302598250534.
# [I 2023-11-09 11:50:22,055] Trial 11 finished with value: 0.22115520156423196 and parameters: {'learning_rate': 0.0009437981148976821, 'hidden_layers': 1, 'num_hidden_units': 46, 'epoch_count': 10502, 'weight_decay': 0.0006151846200815436}. Best is trial 8 with value: 0.24725302598250534.
# [I 2023-11-09 11:50:47,075] Trial 12 finished with value: 0.2668504118007065 and parameters: {'learning_rate': 0.0009967931977852204, 'hidden_layers': 1, 'num_hidden_units': 26, 'epoch_count': 10711, 'weight_decay': 0.0009613939697782859}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:51:12,511] Trial 13 finished with value: 0.20944678035370132 and parameters: {'learning_rate': 0.0009967580201027861, 'hidden_layers': 1, 'num_hidden_units': 27, 'epoch_count': 10892, 'weight_decay': 0.0009556521867165147}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:51:39,126] Trial 14 finished with value: 0.163359882777547 and parameters: {'learning_rate': 0.0004853746007766352, 'hidden_layers': 1, 'num_hidden_units': 26, 'epoch_count': 11403, 'weight_decay': 0.0008447062466313163}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:52:03,202] Trial 15 finished with value: 0.23377045191648535 and parameters: {'learning_rate': 0.00035735548875641973, 'hidden_layers': 1, 'num_hidden_units': 37, 'epoch_count': 10315, 'weight_decay': 0.0009870003102888107}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:52:28,562] Trial 16 finished with value: 0.2042688757395278 and parameters: {'learning_rate': 0.0006150337617151305, 'hidden_layers': 1, 'num_hidden_units': 30, 'epoch_count': 10827, 'weight_decay': 0.0008258533743963096}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:52:56,197] Trial 17 finished with value: 0.16735733826886906 and parameters: {'learning_rate': 0.0005157061432384169, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 11825, 'weight_decay': 0.0009019186050872582}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:53:20,511] Trial 18 finished with value: 0.22200322148933807 and parameters: {'learning_rate': 0.0009179445505654456, 'hidden_layers': 1, 'num_hidden_units': 38, 'epoch_count': 10386, 'weight_decay': 0.0007554275631448819}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:53:46,647] Trial 19 finished with value: 0.14805242729513937 and parameters: {'learning_rate': 0.0006964354583161899, 'hidden_layers': 1, 'num_hidden_units': 46, 'epoch_count': 11135, 'weight_decay': 0.0005084964001018919}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:54:13,942] Trial 20 finished with value: 0.19059057023499731 and parameters: {'learning_rate': 0.0005562898259683099, 'hidden_layers': 1, 'num_hidden_units': 42, 'epoch_count': 11566, 'weight_decay': 0.0009949356680085824}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:55:14,979] Trial 21 finished with value: 0.15580424521825725 and parameters: {'learning_rate': 0.0008883893010189236, 'hidden_layers': 2, 'num_hidden_units': 33, 'epoch_count': 10744, 'weight_decay': 0.0006412957807272244}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:56:14,060] Trial 22 finished with value: 0.17775130614921936 and parameters: {'learning_rate': 0.0007475782060421822, 'hidden_layers': 2, 'num_hidden_units': 31, 'epoch_count': 10612, 'weight_decay': 0.0008898974751991262}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:56:39,912] Trial 23 finished with value: 0.14276722953003923 and parameters: {'learning_rate': 0.0009707146081555717, 'hidden_layers': 1, 'num_hidden_units': 28, 'epoch_count': 10942, 'weight_decay': 0.0006835694476219365}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:57:38,889] Trial 24 finished with value: 0.18284638404228007 and parameters: {'learning_rate': 0.0008978987240607947, 'hidden_layers': 2, 'num_hidden_units': 35, 'epoch_count': 10277, 'weight_decay': 0.0008268997143222274}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:58:04,639] Trial 25 finished with value: 0.19742007109293233 and parameters: {'learning_rate': 0.0007219683487989605, 'hidden_layers': 1, 'num_hidden_units': 36, 'epoch_count': 11019, 'weight_decay': 0.0007912529212299842}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:58:37,361] Trial 26 finished with value: 0.2027402850328119 and parameters: {'learning_rate': 0.0009957114961688842, 'hidden_layers': 2, 'num_hidden_units': 26, 'epoch_count': 10610, 'weight_decay': 0.0009215985911338144}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 11:59:04,454] Trial 27 finished with value: 0.216026229809686 and parameters: {'learning_rate': 0.0008628193048113694, 'hidden_layers': 1, 'num_hidden_units': 31, 'epoch_count': 11471, 'weight_decay': 0.0007093138192704121}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 12:00:07,051] Trial 28 finished with value: 0.21113900433871322 and parameters: {'learning_rate': 0.0007583323921474382, 'hidden_layers': 2, 'num_hidden_units': 29, 'epoch_count': 10179, 'weight_decay': 0.0008596284737009117}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 12:00:30,221] Trial 29 finished with value: 0.2007715230521063 and parameters: {'learning_rate': 0.0006306465141823474, 'hidden_layers': 1, 'num_hidden_units': 32, 'epoch_count': 9849, 'weight_decay': 0.0009383881212500734}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 12:01:33,120] Trial 30 finished with value: 0.24434533669986253 and parameters: {'learning_rate': 0.0009248598292232584, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 11299, 'weight_decay': 0.0007857289683183209}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 12:02:36,419] Trial 31 finished with value: 0.1813644815686034 and parameters: {'learning_rate': 0.0009223611468754554, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 11302, 'weight_decay': 0.0007961783902621696}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 12:03:25,425] Trial 32 finished with value: 0.24575518666005083 and parameters: {'learning_rate': 0.0008430459463404928, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 10689, 'weight_decay': 0.0007520420764010052}. Best is trial 12 with value: 0.2668504118007065.
# [I 2023-11-09 12:04:19,234] Trial 33 finished with value: 0.27025865281256756 and parameters: {'learning_rate': 0.0008757862229430908, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 11714, 'weight_decay': 0.0007432857628870595}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:05:10,849] Trial 34 finished with value: 0.2211673225478094 and parameters: {'learning_rate': 0.0008644406039274575, 'hidden_layers': 2, 'num_hidden_units': 41, 'epoch_count': 11628, 'weight_decay': 0.0007134845258386304}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:06:04,305] Trial 35 finished with value: 0.21797456568843693 and parameters: {'learning_rate': 0.0008164195702086193, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 11763, 'weight_decay': 0.0009456258916069166}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:06:46,017] Trial 36 finished with value: 0.2520769529836846 and parameters: {'learning_rate': 0.0006727548138561489, 'hidden_layers': 2, 'num_hidden_units': 40, 'epoch_count': 9644, 'weight_decay': 0.0008685709163127106}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:07:27,298] Trial 37 finished with value: 0.21637010660303238 and parameters: {'learning_rate': 0.0006932176097893136, 'hidden_layers': 2, 'num_hidden_units': 40, 'epoch_count': 9493, 'weight_decay': 0.0008778304634845476}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:08:09,434] Trial 38 finished with value: 0.24224122373587506 and parameters: {'learning_rate': 0.0006571194711307156, 'hidden_layers': 2, 'num_hidden_units': 38, 'epoch_count': 9618, 'weight_decay': 0.0009235194601752298}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:08:49,707] Trial 39 finished with value: 0.2447029057153983 and parameters: {'learning_rate': 0.0007799516523700737, 'hidden_layers': 2, 'num_hidden_units': 39, 'epoch_count': 9139, 'weight_decay': 0.000999689559317948}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:09:13,192] Trial 40 finished with value: 0.20704772345599512 and parameters: {'learning_rate': 0.0007460472779002606, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 10072, 'weight_decay': 0.0008847887891887126}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:10:01,833] Trial 41 finished with value: 0.24073440590706688 and parameters: {'learning_rate': 0.0008390547010797307, 'hidden_layers': 2, 'num_hidden_units': 43, 'epoch_count': 10494, 'weight_decay': 0.0008321700337899868}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:10:52,577] Trial 42 finished with value: 0.22516679820306107 and parameters: {'learning_rate': 0.0008050593346898664, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 10996, 'weight_decay': 0.0007616245070615922}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:11:39,085] Trial 43 finished with value: 0.22073208945231426 and parameters: {'learning_rate': 0.0009634914447693657, 'hidden_layers': 2, 'num_hidden_units': 40, 'epoch_count': 10652, 'weight_decay': 0.0009380235670652006}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:12:20,702] Trial 44 finished with value: 0.2572063736635482 and parameters: {'learning_rate': 0.0008661963764083446, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9366, 'weight_decay': 0.0008626528223458175}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:13:01,430] Trial 45 finished with value: 0.2374509661335221 and parameters: {'learning_rate': 0.0008924504805110485, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9292, 'weight_decay': 0.0008607056390833016}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:13:45,507] Trial 46 finished with value: 0.2082586995004492 and parameters: {'learning_rate': 0.0005965895367976404, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 9454, 'weight_decay': 0.0009073477337803836}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:14:07,117] Trial 47 finished with value: 0.2189916059956513 and parameters: {'learning_rate': 0.0009531005908107162, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 9017, 'weight_decay': 0.0009652424458206576}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:14:50,042] Trial 48 finished with value: 0.1701420220144663 and parameters: {'learning_rate': 0.000793401176335029, 'hidden_layers': 2, 'num_hidden_units': 39, 'epoch_count': 9691, 'weight_decay': 0.0009616266150605336}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:15:16,035] Trial 49 finished with value: 0.2327462288041881 and parameters: {'learning_rate': 0.0006747733462319615, 'hidden_layers': 1, 'num_hidden_units': 45, 'epoch_count': 9958, 'weight_decay': 0.0008350540713074411}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:15:45,340] Trial 50 finished with value: 0.2186463824263519 and parameters: {'learning_rate': 0.0007269955860277074, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 11981, 'weight_decay': 0.0009984934031542383}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:16:28,537] Trial 51 finished with value: 0.24167759799952213 and parameters: {'learning_rate': 0.0008490647697655864, 'hidden_layers': 2, 'num_hidden_units': 43, 'epoch_count': 9334, 'weight_decay': 0.0007447491949925777}. Best is trial 33 with value: 0.27025865281256756.
# [I 2023-11-09 12:17:16,164] Trial 52 finished with value: 0.280467438999373 and parameters: {'learning_rate': 0.0008715572205385284, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 9742, 'weight_decay': 0.0009001014589229794}. Best is trial 52 with value: 0.280467438999373.
# [I 2023-11-09 12:18:00,363] Trial 53 finished with value: 0.2488951947945954 and parameters: {'learning_rate': 0.0008767085604528986, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9821, 'weight_decay': 0.0008962057831960217}. Best is trial 52 with value: 0.280467438999373.
# [I 2023-11-09 12:18:45,792] Trial 54 finished with value: 0.28310869110597 and parameters: {'learning_rate': 0.0008832884469624671, 'hidden_layers': 2, 'num_hidden_units': 46, 'epoch_count': 9729, 'weight_decay': 0.0008952747226625983}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:19:30,832] Trial 55 finished with value: 0.2513600192513424 and parameters: {'learning_rate': 0.0009302003177826109, 'hidden_layers': 2, 'num_hidden_units': 43, 'epoch_count': 9779, 'weight_decay': 0.0008631485901498449}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:20:19,549] Trial 56 finished with value: 0.19487129760177832 and parameters: {'learning_rate': 0.0009947626158075802, 'hidden_layers': 2, 'num_hidden_units': 46, 'epoch_count': 9444, 'weight_decay': 0.0007972884869681114}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:21:10,160] Trial 57 finished with value: 0.18668469550848293 and parameters: {'learning_rate': 0.0008255998543055831, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 9677, 'weight_decay': 0.000823010291996395}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:22:01,487] Trial 58 finished with value: 0.1702982480250205 and parameters: {'learning_rate': 0.0008952493473747317, 'hidden_layers': 2, 'num_hidden_units': 46, 'epoch_count': 9549, 'weight_decay': 0.0009245239775645457}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:22:52,781] Trial 59 finished with value: 0.17768060041168404 and parameters: {'learning_rate': 0.0009473615980111773, 'hidden_layers': 2, 'num_hidden_units': 40, 'epoch_count': 9987, 'weight_decay': 0.0008792654098499346}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:23:39,678] Trial 60 finished with value: 0.1593179836797742 and parameters: {'learning_rate': 0.0007779595969088037, 'hidden_layers': 2, 'num_hidden_units': 37, 'epoch_count': 9156, 'weight_decay': 0.0009172309902824151}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:24:34,112] Trial 61 finished with value: 0.2123490825325319 and parameters: {'learning_rate': 0.0009246494039902236, 'hidden_layers': 2, 'num_hidden_units': 43, 'epoch_count': 9740, 'weight_decay': 0.000859091777512467}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:25:28,302] Trial 62 finished with value: 0.21465678312808928 and parameters: {'learning_rate': 0.0009084557258352104, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9793, 'weight_decay': 0.0009630776705647625}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:26:21,031] Trial 63 finished with value: 0.1874256467453213 and parameters: {'learning_rate': 0.0008771065477350042, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 9362, 'weight_decay': 0.0008569747908132644}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:27:17,046] Trial 64 finished with value: 0.2516518207078373 and parameters: {'learning_rate': 0.0009513576588622962, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 10141, 'weight_decay': 0.0008949394013993858}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:28:15,271] Trial 65 finished with value: 0.25157662571712525 and parameters: {'learning_rate': 0.0009738803556283253, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 10132, 'weight_decay': 0.000902445040314837}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:29:11,085] Trial 66 finished with value: 0.15832698104098555 and parameters: {'learning_rate': 0.000858850123684887, 'hidden_layers': 2, 'num_hidden_units': 34, 'epoch_count': 9918, 'weight_decay': 0.0009661943789368669}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:30:04,567] Trial 67 finished with value: 0.16456861419541263 and parameters: {'learning_rate': 0.0009488443301879641, 'hidden_layers': 2, 'num_hidden_units': 41, 'epoch_count': 9605, 'weight_decay': 0.0008042711995794786}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:31:02,963] Trial 68 finished with value: 0.23077567112221176 and parameters: {'learning_rate': 0.0009818472725314222, 'hidden_layers': 2, 'num_hidden_units': 46, 'epoch_count': 10358, 'weight_decay': 0.0009420475932030348}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:31:59,274] Trial 69 finished with value: 0.1961071890013639 and parameters: {'learning_rate': 0.0009066643599111702, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 10013, 'weight_decay': 0.0008163769059162555}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:32:54,367] Trial 70 finished with value: 0.188334047125656 and parameters: {'learning_rate': 0.0008228878419967139, 'hidden_layers': 2, 'num_hidden_units': 41, 'epoch_count': 9883, 'weight_decay': 0.0007785998841235271}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:33:51,631] Trial 71 finished with value: 0.23207059620107284 and parameters: {'learning_rate': 0.0009708972458311603, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 10286, 'weight_decay': 0.0009009568393085474}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:34:48,361] Trial 72 finished with value: 0.20149945545473177 and parameters: {'learning_rate': 0.000999945553237848, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 10116, 'weight_decay': 0.0009007844317117505}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:35:46,706] Trial 73 finished with value: 0.18550379746031376 and parameters: {'learning_rate': 0.000935828083885007, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 10463, 'weight_decay': 0.0008484641733690502}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:36:45,299] Trial 74 finished with value: 0.23277698018844944 and parameters: {'learning_rate': 0.0009676653302859637, 'hidden_layers': 2, 'num_hidden_units': 46, 'epoch_count': 10199, 'weight_decay': 0.0009173277162261302}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:37:42,874] Trial 75 finished with value: 0.21120252727116556 and parameters: {'learning_rate': 0.0008820836602406368, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 10116, 'weight_decay': 0.0008833120850364245}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:38:37,270] Trial 76 finished with value: 0.2552961964368005 and parameters: {'learning_rate': 0.0009138699175054926, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 9676, 'weight_decay': 0.0009440619763896992}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:39:31,167] Trial 77 finished with value: 0.19914214861157026 and parameters: {'learning_rate': 0.0008516082634007309, 'hidden_layers': 2, 'num_hidden_units': 43, 'epoch_count': 9533, 'weight_decay': 0.0009812104532500674}. Best is trial 54 with value: 0.28310869110597.
# [I 2023-11-09 12:40:25,471] Trial 78 finished with value: 0.3062523624712202 and parameters: {'learning_rate': 0.0009046786299808608, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9664, 'weight_decay': 0.0008425189043585393}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:40:54,373] Trial 79 finished with value: 0.21526821941077567 and parameters: {'learning_rate': 0.0008090112799873474, 'hidden_layers': 2, 'num_hidden_units': 27, 'epoch_count': 9401, 'weight_decay': 0.0008350061178996844}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:41:46,050] Trial 80 finished with value: 0.19752220160270556 and parameters: {'learning_rate': 0.0009103424427832142, 'hidden_layers': 2, 'num_hidden_units': 46, 'epoch_count': 9225, 'weight_decay': 0.0009526243298223277}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:42:40,571] Trial 81 finished with value: 0.2676411937478078 and parameters: {'learning_rate': 0.0009403778503226999, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9694, 'weight_decay': 0.0009313596599086896}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:43:28,390] Trial 82 finished with value: 0.23626647668281145 and parameters: {'learning_rate': 0.0008805557659163389, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 9680, 'weight_decay': 0.0009294220806631218}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:44:13,423] Trial 83 finished with value: 0.18764000858451566 and parameters: {'learning_rate': 0.0008335099018797022, 'hidden_layers': 2, 'num_hidden_units': 43, 'epoch_count': 9616, 'weight_decay': 0.0008731368774506703}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:44:58,553] Trial 84 finished with value: 0.27963760054963305 and parameters: {'learning_rate': 0.0009152455469187523, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 9517, 'weight_decay': 0.0009792143703192808}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:45:46,554] Trial 85 finished with value: 0.24564519995721812 and parameters: {'learning_rate': 0.0009292846657586754, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 9497, 'weight_decay': 0.0009799938812450715}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:46:33,097] Trial 86 finished with value: 0.17832907303307935 and parameters: {'learning_rate': 0.0008984577738254503, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9276, 'weight_decay': 0.000943409962376801}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:47:30,432] Trial 87 finished with value: 0.2257214454330603 and parameters: {'learning_rate': 0.0008609448204085116, 'hidden_layers': 2, 'num_hidden_units': 29, 'epoch_count': 9728, 'weight_decay': 0.000979173036804176}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:48:18,790] Trial 88 finished with value: 0.22452259037218372 and parameters: {'learning_rate': 0.0009182273762844799, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9555, 'weight_decay': 0.000934400855235158}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:48:53,558] Trial 89 finished with value: 0.18260822916124844 and parameters: {'learning_rate': 0.000943079994359899, 'hidden_layers': 2, 'num_hidden_units': 30, 'epoch_count': 9093, 'weight_decay': 0.0009504542715931467}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:49:46,115] Trial 90 finished with value: 0.22006341519162315 and parameters: {'learning_rate': 0.0008767147984409747, 'hidden_layers': 2, 'num_hidden_units': 45, 'epoch_count': 10836, 'weight_decay': 0.0008423875686100995}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:50:30,068] Trial 91 finished with value: 0.22151434181837956 and parameters: {'learning_rate': 0.0008392307109370719, 'hidden_layers': 2, 'num_hidden_units': 39, 'epoch_count': 9446, 'weight_decay': 0.000873845937134844}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:51:16,581] Trial 92 finished with value: 0.19881443312966054 and parameters: {'learning_rate': 0.0009004651487256823, 'hidden_layers': 2, 'num_hidden_units': 43, 'epoch_count': 9850, 'weight_decay': 0.0009164939188082701}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:52:01,931] Trial 93 finished with value: 0.24145829798183321 and parameters: {'learning_rate': 0.0009797815429001373, 'hidden_layers': 2, 'num_hidden_units': 41, 'epoch_count': 9668, 'weight_decay': 0.0009931101477841802}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:52:46,083] Trial 94 finished with value: 0.1987803148055165 and parameters: {'learning_rate': 0.0008043724797699257, 'hidden_layers': 2, 'num_hidden_units': 40, 'epoch_count': 9374, 'weight_decay': 0.0008121351941413612}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:53:41,402] Trial 95 finished with value: 0.27238162063989774 and parameters: {'learning_rate': 0.000932761663734171, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 9773, 'weight_decay': 0.0007720736431349646}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:54:33,799] Trial 96 finished with value: 0.2468243023041166 and parameters: {'learning_rate': 0.0009537723192839522, 'hidden_layers': 2, 'num_hidden_units': 42, 'epoch_count': 9760, 'weight_decay': 0.0007673647679076689}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:55:29,074] Trial 97 finished with value: 0.21550345627724235 and parameters: {'learning_rate': 0.0009324284704401442, 'hidden_layers': 2, 'num_hidden_units': 46, 'epoch_count': 11228, 'weight_decay': 0.000737970856695068}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:55:52,987] Trial 98 finished with value: 0.2113782815330391 and parameters: {'learning_rate': 0.0008607358430713171, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 9955, 'weight_decay': 0.0007804724588256435}. Best is trial 78 with value: 0.3062523624712202.
# [I 2023-11-09 12:56:40,698] Trial 99 finished with value: 0.17822492235937654 and parameters: {'learning_rate': 0.0009205252937575582, 'hidden_layers': 2, 'num_hidden_units': 44, 'epoch_count': 9898, 'weight_decay': 0.0009664406989621044}. Best is trial 78 with value: 0.3062523624712202.

# %%
 best_trial = study.best_trial
score = best_trial.value
best_params = best_trial.params
print(f'Best score: {score} \nBest Hyperparameters: ')
for key,value in best_params.items():
    print(f'{key}: {value}')
# Out:
# Best score: 0.3062523624712202
# Best Hyperparameters:
# learning_rate: 0.0009046786299808608
# hidden_layers: 2
# num_hidden_units: 44
# epoch_count: 9664
# weight_decay: 0.0008425189043585393

# %%
# Save model 
from pathlib import Path
best_model_weights = best_trial.user_attrs.get('model_weights', None)
# 1. Create models directory
MODEL_PATH = Path('models')
MODEL_PATH.mkdir(parents=True, exist_ok=True)

# 2. Create model save path
MODEL_NAME = "Neural_1.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save state_dict
print(f'Save model to: {MODEL_SAVE_PATH}')
torch.save(obj=best_model_weights, f=MODEL_SAVE_PATH)
# Out:
# Save model to: models/Neural_1.pth

# %% [markdown]
# ### Study #2 Neural Network

# %%
def objective(trial):
    #define the search space
    learning_rate= trial.suggest_float("learning_rate", 1e-4, 1e-3)
    hidden_layers= trial.suggest_int("hidden_layers", 1, 1)
    num_hidden_units= trial.suggest_int("num_hidden_units", 16, 46)
    epoch_count= trial.suggest_int("epoch_count", 9000, 11000)
    weight_decay = trial.suggest_float("weight_decay", 1e-4, 1e-3)
    
    #create the model
    model = NeuralNetworkWithHyper(hidden_layers, 
                                   num_hidden_units,
                                  ).to('mps')
    optimizer = torch.optim.SGD(model.parameters(), learning_rate, weight_decay
                               )
    loss_fn = torch.nn.L1Loss()
    
    #testing loop
    for epoch in range(epoch_count):
        #convert into train
        model.train()

        #fit data
        train_pred = model(X_train)

        #calculate loss
        train_loss = loss_fn(train_pred, y_train)


        #zero gradients
        optimizer.zero_grad()

        #back propagation
        train_loss.backward()

        #gradient descent
        optimizer.step()

        #testing
        model.eval()
        with torch.inference_mode():
            test_pred = model(X_test)
            test_loss = loss_fn(test_pred, y_test)
            spear_pred = test_pred.to('cpu')
     
    #save model weights
    trial.set_user_attr('model_weights', model.state_dict())
    
    #spearman correlation evaluation        
    validation_metric = stats.spearmanr(y_test.to('cpu'), spear_pred).statistic
    return validation_metric

#Create an Optuna Study
study = optuna.create_study(direction='maximize')

#Perform hyperparameter optimization
study.optimize(objective, n_trials=100)

#Print best spearman correlation coefficient
best_validation_metric = study.best_value
# Out:
# [I 2023-11-13 11:04:20,901] A new study created in memory with name: no-name-5e266c47-670f-43f1-88ff-568da9a9776c
# [I 2023-11-13 11:04:43,107] Trial 0 finished with value: 0.23844960050271136 and parameters: {'learning_rate': 0.0006639474453701077, 'hidden_layers': 1, 'num_hidden_units': 37, 'epoch_count': 9011, 'weight_decay': 0.000135004972249129}. Best is trial 0 with value: 0.23844960050271136.
# [I 2023-11-13 11:05:07,671] Trial 1 finished with value: 0.19286190787982227 and parameters: {'learning_rate': 0.0007870254513215061, 'hidden_layers': 1, 'num_hidden_units': 31, 'epoch_count': 10250, 'weight_decay': 0.0008154235315091069}. Best is trial 0 with value: 0.23844960050271136.
# [I 2023-11-13 11:05:34,404] Trial 2 finished with value: 0.2145840572266244 and parameters: {'learning_rate': 0.0009662799090055908, 'hidden_layers': 1, 'num_hidden_units': 37, 'epoch_count': 10822, 'weight_decay': 0.00012248821239373354}. Best is trial 0 with value: 0.23844960050271136.
# [I 2023-11-13 11:06:00,894] Trial 3 finished with value: 0.24134943359229472 and parameters: {'learning_rate': 0.0008799433086900657, 'hidden_layers': 1, 'num_hidden_units': 38, 'epoch_count': 10984, 'weight_decay': 0.0005242521244280289}. Best is trial 3 with value: 0.24134943359229472.
# [I 2023-11-13 11:06:23,776] Trial 4 finished with value: 0.16007487176539037 and parameters: {'learning_rate': 0.0004200226296469186, 'hidden_layers': 1, 'num_hidden_units': 33, 'epoch_count': 9608, 'weight_decay': 0.0001607922730493576}. Best is trial 3 with value: 0.24134943359229472.
# [I 2023-11-13 11:06:46,120] Trial 5 finished with value: 0.16265394771548808 and parameters: {'learning_rate': 0.0005425703389050527, 'hidden_layers': 1, 'num_hidden_units': 30, 'epoch_count': 9432, 'weight_decay': 0.0002413984063264092}. Best is trial 3 with value: 0.24134943359229472.
# [I 2023-11-13 11:07:12,578] Trial 6 finished with value: 0.2457868358949476 and parameters: {'learning_rate': 0.000579350264124852, 'hidden_layers': 1, 'num_hidden_units': 21, 'epoch_count': 10850, 'weight_decay': 0.000969305905247422}. Best is trial 6 with value: 0.2457868358949476.
# [I 2023-11-13 11:07:36,104] Trial 7 finished with value: 0.1855989696276629 and parameters: {'learning_rate': 0.0005426230571768632, 'hidden_layers': 1, 'num_hidden_units': 33, 'epoch_count': 9415, 'weight_decay': 0.0005305394473581071}. Best is trial 6 with value: 0.2457868358949476.
# [I 2023-11-13 11:07:58,335] Trial 8 finished with value: 0.2129840873943967 and parameters: {'learning_rate': 0.0005324200357844786, 'hidden_layers': 1, 'num_hidden_units': 20, 'epoch_count': 9117, 'weight_decay': 0.00036866081381713254}. Best is trial 6 with value: 0.2457868358949476.
# [I 2023-11-13 11:08:20,817] Trial 9 finished with value: 0.25663489173413584 and parameters: {'learning_rate': 0.0007168121612960421, 'hidden_layers': 1, 'num_hidden_units': 21, 'epoch_count': 9296, 'weight_decay': 0.0003613437055025163}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:08:44,877] Trial 10 finished with value: 0.075578372933464 and parameters: {'learning_rate': 0.00016324757191719583, 'hidden_layers': 1, 'num_hidden_units': 16, 'epoch_count': 9985, 'weight_decay': 0.0003893721719065148}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:09:10,336] Trial 11 finished with value: 0.2261557806779201 and parameters: {'learning_rate': 0.0007520088621953925, 'hidden_layers': 1, 'num_hidden_units': 24, 'epoch_count': 10533, 'weight_decay': 0.00084795114752787}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:09:34,350] Trial 12 finished with value: 0.17441421980021127 and parameters: {'learning_rate': 0.0006576647991463607, 'hidden_layers': 1, 'num_hidden_units': 46, 'epoch_count': 9958, 'weight_decay': 0.0009263183750279143}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:09:59,434] Trial 13 finished with value: 0.171364894579839 and parameters: {'learning_rate': 0.0003787049537390848, 'hidden_layers': 1, 'num_hidden_units': 24, 'epoch_count': 10429, 'weight_decay': 0.0006999921331169679}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:10:22,936] Trial 14 finished with value: 0.18783371985909655 and parameters: {'learning_rate': 0.0008185000927948778, 'hidden_layers': 1, 'num_hidden_units': 24, 'epoch_count': 9751, 'weight_decay': 0.0006640800346580614}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:10:48,742] Trial 15 finished with value: 0.19590719277233543 and parameters: {'learning_rate': 0.0006787210765052724, 'hidden_layers': 1, 'num_hidden_units': 16, 'epoch_count': 10654, 'weight_decay': 0.0009932442812289268}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:11:13,614] Trial 16 finished with value: 0.222508486934392 and parameters: {'learning_rate': 0.0009792614920343654, 'hidden_layers': 1, 'num_hidden_units': 21, 'epoch_count': 10219, 'weight_decay': 0.0006612283125968887}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:11:36,969] Trial 17 finished with value: 0.20313174790983282 and parameters: {'learning_rate': 0.0008767279578994778, 'hidden_layers': 1, 'num_hidden_units': 26, 'epoch_count': 9258, 'weight_decay': 0.0009888514201992936}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:12:01,208] Trial 18 finished with value: 0.21946656898176153 and parameters: {'learning_rate': 0.0007057993914511582, 'hidden_layers': 1, 'num_hidden_units': 20, 'epoch_count': 9748, 'weight_decay': 0.0003929009595314319}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:12:26,211] Trial 19 finished with value: 0.20668746088855322 and parameters: {'learning_rate': 0.0005965425837186166, 'hidden_layers': 1, 'num_hidden_units': 28, 'epoch_count': 10196, 'weight_decay': 0.0007694522765354493}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:12:52,012] Trial 20 finished with value: 0.08909865672616948 and parameters: {'learning_rate': 0.0004451250344979572, 'hidden_layers': 1, 'num_hidden_units': 19, 'epoch_count': 10744, 'weight_decay': 0.0005880454143527813}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:13:18,285] Trial 21 finished with value: 0.2447136799230227 and parameters: {'learning_rate': 0.0008707993196992227, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 10889, 'weight_decay': 0.00047256485247616873}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:13:44,724] Trial 22 finished with value: 0.20149070141103695 and parameters: {'learning_rate': 0.0007684769464772503, 'hidden_layers': 1, 'num_hidden_units': 46, 'epoch_count': 10930, 'weight_decay': 0.00046882219643495297}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:14:10,023] Trial 23 finished with value: 0.21575687461907528 and parameters: {'learning_rate': 0.0009091117697093966, 'hidden_layers': 1, 'num_hidden_units': 42, 'epoch_count': 10476, 'weight_decay': 0.0003023098721371267}. Best is trial 9 with value: 0.25663489173413584.
# [I 2023-11-13 11:14:35,965] Trial 24 finished with value: 0.26219662749492967 and parameters: {'learning_rate': 0.0008242061159140467, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 10703, 'weight_decay': 0.000447199175880651}. Best is trial 24 with value: 0.26219662749492967.
# [I 2023-11-13 11:15:01,942] Trial 25 finished with value: 0.26669755273003487 and parameters: {'learning_rate': 0.0007332005639693344, 'hidden_layers': 1, 'num_hidden_units': 27, 'epoch_count': 10650, 'weight_decay': 0.00029645611856825294}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:15:27,673] Trial 26 finished with value: 0.23857687083027496 and parameters: {'learning_rate': 0.0008041231290832195, 'hidden_layers': 1, 'num_hidden_units': 27, 'epoch_count': 10610, 'weight_decay': 0.00026244813949473426}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:15:52,628] Trial 27 finished with value: 0.1793369103712812 and parameters: {'learning_rate': 0.0007268851863280319, 'hidden_layers': 1, 'num_hidden_units': 34, 'epoch_count': 10347, 'weight_decay': 0.00032966310478091545}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:16:17,801] Trial 28 finished with value: 0.1485341241610149 and parameters: {'learning_rate': 0.0008170957778636033, 'hidden_layers': 1, 'num_hidden_units': 40, 'epoch_count': 10121, 'weight_decay': 0.00042002825535170357}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:16:41,887] Trial 29 finished with value: 0.22925269198196696 and parameters: {'learning_rate': 0.0006731347657474556, 'hidden_layers': 1, 'num_hidden_units': 29, 'epoch_count': 9845, 'weight_decay': 0.00020108398664759927}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:17:03,791] Trial 30 finished with value: 0.22681929229745787 and parameters: {'learning_rate': 0.0007365107974607486, 'hidden_layers': 1, 'num_hidden_units': 35, 'epoch_count': 9080, 'weight_decay': 0.0003128388619484632}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:17:29,950] Trial 31 finished with value: 0.1606209894143536 and parameters: {'learning_rate': 0.0006074203234958006, 'hidden_layers': 1, 'num_hidden_units': 22, 'epoch_count': 10778, 'weight_decay': 0.00044469554248339647}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:17:55,704] Trial 32 finished with value: 0.16534323483107735 and parameters: {'learning_rate': 0.0006355929860177644, 'hidden_layers': 1, 'num_hidden_units': 18, 'epoch_count': 10661, 'weight_decay': 0.00034038410902187746}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:18:20,840] Trial 33 finished with value: 0.20896351224921395 and parameters: {'learning_rate': 0.0007174136842082511, 'hidden_layers': 1, 'num_hidden_units': 23, 'epoch_count': 10377, 'weight_decay': 0.0005758531650907122}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:18:47,858] Trial 34 finished with value: 0.2247147304081527 and parameters: {'learning_rate': 0.0007935195928005144, 'hidden_layers': 1, 'num_hidden_units': 26, 'epoch_count': 10999, 'weight_decay': 0.0001075343462046024}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:19:14,258] Trial 35 finished with value: 0.19343294088391705 and parameters: {'learning_rate': 0.0009092028162224776, 'hidden_layers': 1, 'num_hidden_units': 31, 'epoch_count': 10794, 'weight_decay': 0.000502952488500539}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:19:39,710] Trial 36 finished with value: 0.21688928873293456 and parameters: {'learning_rate': 0.0008461664403980597, 'hidden_layers': 1, 'num_hidden_units': 18, 'epoch_count': 10578, 'weight_decay': 0.00042769334037651217}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:20:02,626] Trial 37 finished with value: 0.19495569556150305 and parameters: {'learning_rate': 0.0009323649719597296, 'hidden_layers': 1, 'num_hidden_units': 37, 'epoch_count': 9513, 'weight_decay': 0.0002552881667297123}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:20:28,889] Trial 38 finished with value: 0.24856007204494387 and parameters: {'learning_rate': 0.0007609850945213279, 'hidden_layers': 1, 'num_hidden_units': 22, 'epoch_count': 10862, 'weight_decay': 0.00016182176233709474}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:20:53,421] Trial 39 finished with value: 0.14813256046434609 and parameters: {'learning_rate': 0.0007693548341474141, 'hidden_layers': 1, 'num_hidden_units': 26, 'epoch_count': 10097, 'weight_decay': 0.00018480597321233685}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:21:19,321] Trial 40 finished with value: 0.20137824561895698 and parameters: {'learning_rate': 0.0008385326318536651, 'hidden_layers': 1, 'num_hidden_units': 32, 'epoch_count': 10726, 'weight_decay': 0.0001238193781079893}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:21:45,634] Trial 41 finished with value: 0.1748530442982479 and parameters: {'learning_rate': 0.00069010208544159, 'hidden_layers': 1, 'num_hidden_units': 22, 'epoch_count': 10879, 'weight_decay': 0.00017497961421035913}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:22:12,098] Trial 42 finished with value: 0.2211444273566075 and parameters: {'learning_rate': 0.0007518347197640093, 'hidden_layers': 1, 'num_hidden_units': 18, 'epoch_count': 10894, 'weight_decay': 0.00037124125580307926}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:22:37,607] Trial 43 finished with value: 0.19820546593622143 and parameters: {'learning_rate': 0.0006285166323244095, 'hidden_layers': 1, 'num_hidden_units': 25, 'epoch_count': 10512, 'weight_decay': 0.00023769880579543466}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:23:03,544] Trial 44 finished with value: 0.2629714725932532 and parameters: {'learning_rate': 0.0007843112389504558, 'hidden_layers': 1, 'num_hidden_units': 28, 'epoch_count': 10688, 'weight_decay': 0.0002757630313968045}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:23:28,389] Trial 45 finished with value: 0.24040040547070962 and parameters: {'learning_rate': 0.000778245366228994, 'hidden_layers': 1, 'num_hidden_units': 30, 'epoch_count': 10302, 'weight_decay': 0.0002858825639255812}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:23:54,337] Trial 46 finished with value: 0.2530576303401665 and parameters: {'learning_rate': 0.0008478980545230516, 'hidden_layers': 1, 'num_hidden_units': 28, 'epoch_count': 10668, 'weight_decay': 0.0002181925033760795}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:24:16,915] Trial 47 finished with value: 0.21393895154511172 and parameters: {'learning_rate': 0.0009499732262365713, 'hidden_layers': 1, 'num_hidden_units': 28, 'epoch_count': 9277, 'weight_decay': 0.00022296172661542357}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:27:58,544] Trial 48 finished with value: 0.22438342352370153 and parameters: {'learning_rate': 0.0008444031924925251, 'hidden_layers': 1, 'num_hidden_units': 35, 'epoch_count': 10693, 'weight_decay': 0.0003536068054273517}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:30:38,493] Trial 49 finished with value: 0.16572392350047382 and parameters: {'learning_rate': 0.0008830259552712804, 'hidden_layers': 1, 'num_hidden_units': 29, 'epoch_count': 10423, 'weight_decay': 0.0002849570419688432}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:31:02,555] Trial 50 finished with value: 0.2378745271707575 and parameters: {'learning_rate': 0.000793534026829382, 'hidden_layers': 1, 'num_hidden_units': 32, 'epoch_count': 9612, 'weight_decay': 0.0003996651957959916}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:31:28,495] Trial 51 finished with value: 0.24067896363033286 and parameters: {'learning_rate': 0.0007278935331515357, 'hidden_layers': 1, 'num_hidden_units': 23, 'epoch_count': 10566, 'weight_decay': 0.00016415879088904433}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:31:54,870] Trial 52 finished with value: 0.141133814761644 and parameters: {'learning_rate': 0.0009966252399742268, 'hidden_layers': 1, 'num_hidden_units': 25, 'epoch_count': 10832, 'weight_decay': 0.00020662647575270287}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:32:21,011] Trial 53 finished with value: 0.26495639588539543 and parameters: {'learning_rate': 0.0006983505978813676, 'hidden_layers': 1, 'num_hidden_units': 28, 'epoch_count': 10637, 'weight_decay': 0.00013996248555410572}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:32:47,153] Trial 54 finished with value: 0.19766069506321127 and parameters: {'learning_rate': 0.000687054164973841, 'hidden_layers': 1, 'num_hidden_units': 28, 'epoch_count': 10630, 'weight_decay': 0.00013778529904324408}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:33:13,209] Trial 55 finished with value: 0.26620014347804044 and parameters: {'learning_rate': 0.00081820233775732, 'hidden_layers': 1, 'num_hidden_units': 30, 'epoch_count': 10507, 'weight_decay': 0.00023005041829694985}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:33:38,839] Trial 56 finished with value: 0.22454885250326828 and parameters: {'learning_rate': 0.0006610842373168987, 'hidden_layers': 1, 'num_hidden_units': 30, 'epoch_count': 10496, 'weight_decay': 0.0002734474950087723}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:34:03,944] Trial 57 finished with value: 0.18311124997971398 and parameters: {'learning_rate': 0.0007115629997797666, 'hidden_layers': 1, 'num_hidden_units': 32, 'epoch_count': 10279, 'weight_decay': 0.00030575249794991227}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:34:30,067] Trial 58 finished with value: 0.21548213232465238 and parameters: {'learning_rate': 0.0008039747067882909, 'hidden_layers': 1, 'num_hidden_units': 38, 'epoch_count': 10737, 'weight_decay': 0.00034121457560069607}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:34:55,850] Trial 59 finished with value: 0.2411453970354071 and parameters: {'learning_rate': 0.0007495415169739235, 'hidden_layers': 1, 'num_hidden_units': 29, 'epoch_count': 10461, 'weight_decay': 0.00024031938600654058}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:35:21,527] Trial 60 finished with value: 0.233832179147667 and parameters: {'learning_rate': 0.0005714651817790762, 'hidden_layers': 1, 'num_hidden_units': 34, 'epoch_count': 10566, 'weight_decay': 0.0003608719341739701}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:35:47,542] Trial 61 finished with value: 0.21329496817689325 and parameters: {'learning_rate': 0.0008324839903794724, 'hidden_layers': 1, 'num_hidden_units': 31, 'epoch_count': 10689, 'weight_decay': 0.000220862727932659}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:36:13,671] Trial 62 finished with value: 0.2521472097959022 and parameters: {'learning_rate': 0.0008602975069804548, 'hidden_layers': 1, 'num_hidden_units': 27, 'epoch_count': 10630, 'weight_decay': 0.00025718755054360417}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:36:40,109] Trial 63 finished with value: 0.2342909808223406 and parameters: {'learning_rate': 0.0008055836798751491, 'hidden_layers': 1, 'num_hidden_units': 25, 'epoch_count': 10953, 'weight_decay': 0.00020511745686653093}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:37:06,488] Trial 64 finished with value: 0.22672995615923863 and parameters: {'learning_rate': 0.0008830652177866577, 'hidden_layers': 1, 'num_hidden_units': 28, 'epoch_count': 10789, 'weight_decay': 0.0003169400512897348}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:37:30,590] Trial 65 finished with value: 0.18552646818885682 and parameters: {'learning_rate': 0.0007764944454154776, 'hidden_layers': 1, 'num_hidden_units': 27, 'epoch_count': 9901, 'weight_decay': 0.0001340928051605482}. Best is trial 25 with value: 0.26669755273003487.
# [I 2023-11-13 11:37:55,865] Trial 66 finished with value: 0.2687073913773086 and parameters: {'learning_rate': 0.0007027132999867218, 'hidden_layers': 1, 'num_hidden_units': 30, 'epoch_count': 10410, 'weight_decay': 0.000278440968264958}. Best is trial 66 with value: 0.2687073913773086.
# [I 2023-11-13 11:38:22,793] Trial 67 finished with value: 0.25779917954555065 and parameters: {'learning_rate': 0.0007031832336661601, 'hidden_layers': 1, 'num_hidden_units': 33, 'epoch_count': 10403, 'weight_decay': 0.0002856090539473809}. Best is trial 66 with value: 0.2687073913773086.
# [I 2023-11-13 11:38:47,772] Trial 68 finished with value: 0.272341441823965 and parameters: {'learning_rate': 0.0006885452419218885, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 10349, 'weight_decay': 0.0003079084900296275}. Best is trial 68 with value: 0.272341441823965.
# [I 2023-11-13 11:39:13,295] Trial 69 finished with value: 0.24580726199690228 and parameters: {'learning_rate': 0.0007363655530463002, 'hidden_layers': 1, 'num_hidden_units': 44, 'epoch_count': 10184, 'weight_decay': 0.00025497810928394414}. Best is trial 68 with value: 0.272341441823965.
# [I 2023-11-13 11:39:38,610] Trial 70 finished with value: 0.19650897716069157 and parameters: {'learning_rate': 0.0006575919029772146, 'hidden_layers': 1, 'num_hidden_units': 40, 'epoch_count': 10335, 'weight_decay': 0.0003254487064679026}. Best is trial 68 with value: 0.272341441823965.
# [I 2023-11-13 11:40:04,072] Trial 71 finished with value: 0.2674934973182896 and parameters: {'learning_rate': 0.0007034319540072625, 'hidden_layers': 1, 'num_hidden_units': 44, 'epoch_count': 10395, 'weight_decay': 0.00029725372239733605}. Best is trial 68 with value: 0.272341441823965.
# [I 2023-11-13 11:40:29,963] Trial 72 finished with value: 0.2234507811762119 and parameters: {'learning_rate': 0.0007014517548581357, 'hidden_layers': 1, 'num_hidden_units': 45, 'epoch_count': 10541, 'weight_decay': 0.00029200139394761174}. Best is trial 68 with value: 0.272341441823965.
# [I 2023-11-13 11:40:55,364] Trial 73 finished with value: 0.22875999644580816 and parameters: {'learning_rate': 0.0007342419249883544, 'hidden_layers': 1, 'num_hidden_units': 42, 'epoch_count': 10431, 'weight_decay': 0.00018464305719237149}. Best is trial 68 with value: 0.272341441823965.
# [I 2023-11-13 11:41:20,326] Trial 74 finished with value: 0.21431290633474295 and parameters: {'learning_rate': 0.0008217624725769575, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 10246, 'weight_decay': 0.00038429653497155025}. Best is trial 68 with value: 0.272341441823965.
# [I 2023-11-13 11:41:45,149] Trial 75 finished with value: 0.22669561337243577 and parameters: {'learning_rate': 0.0006756378594908219, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 10046, 'weight_decay': 0.0003119015383901094}. Best is trial 68 with value: 0.272341441823965.
# [I 2023-11-13 11:42:10,480] Trial 76 finished with value: 0.3024147243929939 and parameters: {'learning_rate': 0.0007691427880214144, 'hidden_layers': 1, 'num_hidden_units': 45, 'epoch_count': 10360, 'weight_decay': 0.0003399643229148254}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:42:36,167] Trial 77 finished with value: 0.21619278110254697 and parameters: {'learning_rate': 0.0007623826615210239, 'hidden_layers': 1, 'num_hidden_units': 45, 'epoch_count': 10369, 'weight_decay': 0.0002712227882646151}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:43:01,731] Trial 78 finished with value: 0.2011685974955983 and parameters: {'learning_rate': 0.0007819577647445772, 'hidden_layers': 1, 'num_hidden_units': 46, 'epoch_count': 10507, 'weight_decay': 0.00023733060031666796}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:43:26,932] Trial 79 finished with value: 0.21297196641081922 and parameters: {'learning_rate': 0.0007137826028528412, 'hidden_layers': 1, 'num_hidden_units': 44, 'epoch_count': 10170, 'weight_decay': 0.00033452598494644137}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:43:51,976] Trial 80 finished with value: 0.1920904297213814 and parameters: {'learning_rate': 0.0006316787822937377, 'hidden_layers': 1, 'num_hidden_units': 30, 'epoch_count': 10324, 'weight_decay': 0.00014960442215496963}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:44:17,726] Trial 81 finished with value: 0.28634050446798104 and parameters: {'learning_rate': 0.000747793682030578, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 10593, 'weight_decay': 0.0003491931044950619}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:44:42,935] Trial 82 finished with value: 0.2648796296560713 and parameters: {'learning_rate': 0.0007541594580286995, 'hidden_layers': 1, 'num_hidden_units': 45, 'epoch_count': 10472, 'weight_decay': 0.0003563622068761185}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:45:08,238] Trial 83 finished with value: 0.21233022766918916 and parameters: {'learning_rate': 0.0007533171927106138, 'hidden_layers': 1, 'num_hidden_units': 45, 'epoch_count': 10463, 'weight_decay': 0.0003536068793232626}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:45:33,266] Trial 84 finished with value: 0.2171126290784826 and parameters: {'learning_rate': 0.0006854777325714571, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 10260, 'weight_decay': 0.00040317126332283215}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:45:59,294] Trial 85 finished with value: 0.24734168873274803 and parameters: {'learning_rate': 0.000647391960333359, 'hidden_layers': 1, 'num_hidden_units': 44, 'epoch_count': 10583, 'weight_decay': 0.00037334227696302156}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:46:25,660] Trial 86 finished with value: 0.1927195985541163 and parameters: {'learning_rate': 0.0007226416368964573, 'hidden_layers': 1, 'num_hidden_units': 42, 'epoch_count': 10395, 'weight_decay': 0.00031482625107645497}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:46:51,329] Trial 87 finished with value: 0.19033311156530525 and parameters: {'learning_rate': 0.0006919746348759373, 'hidden_layers': 1, 'num_hidden_units': 40, 'epoch_count': 10451, 'weight_decay': 0.000298536940869721}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:47:17,362] Trial 88 finished with value: 0.19094701693723887 and parameters: {'learning_rate': 0.0007471286636117247, 'hidden_layers': 1, 'num_hidden_units': 46, 'epoch_count': 10610, 'weight_decay': 0.00034285417241878527}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:47:43,901] Trial 89 finished with value: 0.22918221070709047 and parameters: {'learning_rate': 0.0006684611122989301, 'hidden_layers': 1, 'num_hidden_units': 45, 'epoch_count': 10529, 'weight_decay': 0.00019798014036268374}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:48:09,524] Trial 90 finished with value: 0.2746556518366288 and parameters: {'learning_rate': 0.000810869103513404, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 10361, 'weight_decay': 0.00011168199413667042}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:52:58,484] Trial 91 finished with value: 0.2730094426966796 and parameters: {'learning_rate': 0.0008128588217033079, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 10348, 'weight_decay': 0.00012418871745579037}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:57:54,484] Trial 92 finished with value: 0.25896414074494206 and parameters: {'learning_rate': 0.0008063984276681031, 'hidden_layers': 1, 'num_hidden_units': 39, 'epoch_count': 10135, 'weight_decay': 0.00010348572874386614}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:58:59,129] Trial 93 finished with value: 0.29081718773593135 and parameters: {'learning_rate': 0.0007812276325440197, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 10224, 'weight_decay': 0.00015206831826849055}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 11:59:34,965] Trial 94 finished with value: 0.24833628277407815 and parameters: {'learning_rate': 0.0007908040842959982, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 10361, 'weight_decay': 0.00016747741327567878}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 12:00:41,694] Trial 95 finished with value: 0.21184067461025416 and parameters: {'learning_rate': 0.000818925997577485, 'hidden_layers': 1, 'num_hidden_units': 43, 'epoch_count': 10310, 'weight_decay': 0.00015525732358524853}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 12:02:03,966] Trial 96 finished with value: 0.22852565742997683 and parameters: {'learning_rate': 0.0007756926793070703, 'hidden_layers': 1, 'num_hidden_units': 39, 'epoch_count': 10400, 'weight_decay': 0.00011862007919158088}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 12:03:26,824] Trial 97 finished with value: 0.21377868520669835 and parameters: {'learning_rate': 0.0007324440188019213, 'hidden_layers': 1, 'num_hidden_units': 42, 'epoch_count': 10229, 'weight_decay': 0.0001798481577554414}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 12:05:24,500] Trial 98 finished with value: 0.20608881897742093 and parameters: {'learning_rate': 0.0008612915933549307, 'hidden_layers': 1, 'num_hidden_units': 44, 'epoch_count': 10282, 'weight_decay': 0.00011039240202972899}. Best is trial 76 with value: 0.3024147243929939.
# [I 2023-11-13 12:06:33,427] Trial 99 finished with value: 0.26301816082629237 and parameters: {'learning_rate': 0.0008272122436890334, 'hidden_layers': 1, 'num_hidden_units': 41, 'epoch_count': 10043, 'weight_decay': 0.0002252563114017792}. Best is trial 76 with value: 0.3024147243929939.

# %%
best_trial = study.best_trial
best_params = best_trial.params
best_score = best_trial.value
print(f'Best Score: {best_score} \nHyperparameters: ')
for key,value in best_params.items():
    print(f'{key}: {value}')
# Out:
# Best Score: 0.3472488958701495
# Hyperparameters:
# learning_rate: 0.0009532446966730183
# hidden_layers: 1
# num_hidden_units: 28
# epoch_count: 10079
# weight_decay: 0.0004377217621912963

# %%
from pathlib import Path
best_model_weights = best_trial.user_attrs.get('model_weights', None)
# 1. Create models directory
MODEL_PATH = Path('models')
MODEL_PATH.mkdir(parents=True, exist_ok=True)

# 2. Create model save path
MODEL_NAME = "Neural_2.pth"
MODEL_SAVE_PATH = MODEL_PATH / MODEL_NAME

# 3. Save state_dict
print(f'Save model to: {MODEL_SAVE_PATH}')
torch.save(obj=best_model_weights, f=MODEL_SAVE_PATH)
# Out:
# Save model to: models/Neural_2.pth

# %% [markdown]
# ### Study #3 Random Forest

# %%
X_train, X_test, y_train, y_test = X_train.to('cpu'), X_test.to('cpu'), y_train.to('cpu').squeeze(), y_test.to('cpu').squeeze()

# %%
X_train.numpy(), X_test.numpy(), y_train.numpy(), y_test.numpy()
# Out:
# (array([[-1.8840996 , -1.2298406 , -0.08687859, ...,  0.21039778,
#          -0.24490474, -1.0782467 ],
#         [-3.0310247 , -1.0652962 , -0.6179891 , ...,  0.06913669,
#          -0.13375966, -0.15979725],
#         [-2.4773939 , -0.24320649, -2.6922863 , ...,  0.37434563,
#          -0.5727486 ,  0.52930886],
#         ...,
#         [ 4.008305  , -3.0478313 , -0.4981839 , ..., -0.25590926,
#          -0.03921561,  0.6463667 ],
#         [-2.3074343 ,  2.9922462 ,  2.0321922 , ..., -0.24898356,
#           0.5775757 ,  0.80868113],
#         [ 3.7405992 , -0.9258261 ,  0.52959573, ..., -0.14529   ,
#          -0.31167406,  0.21507934]], dtype=float32),
#  array([[-2.7682261 , -0.8817636 ,  2.15579   , ...,  0.8664899 ,
#           0.33826873,  0.36335376],
#         [ 1.9744093 ,  5.584851  , -1.1742501 , ..., -1.0187863 ,
#          -0.7615747 ,  0.53597295],
#         [ 1.2637563 , -2.2719896 ,  0.30258185, ...,  1.1502167 ,
#           0.83102214,  0.27453494],
#         ...,
#         [-0.25826934,  1.5601684 ,  1.5574484 , ..., -0.14668359,
#           0.5901273 , -0.06250487],
#         [-3.2291915 , -0.75530446, -3.2642603 , ..., -0.17729747,
#          -0.42617616,  0.28408334],
#         [ 3.7781994 ,  1.2022041 ,  0.8310125 , ...,  0.29014942,
#           0.12014395, -0.41146746]], dtype=float32),
#  array([ 0.02409961,  2.2718246 , -0.02122719, ..., -0.3002715 ,
#         -1.6995709 , -4.0306363 ], dtype=float32),
#  array([-5.64675987e-01, -1.01041508e+00,  1.67995691e-01,  3.66323628e-02,
#          2.10924163e-01, -6.87728524e-02,  8.70289803e-01,  8.23069215e-01,
#          3.83148432e-01, -2.60635018e-01, -5.56196570e-01, -3.00933689e-01,
#          2.90748477e-01, -1.37358215e-02,  3.06889206e-01,  1.90615714e-01,
#         -1.94085091e-01,  4.02618378e-01,  2.46767700e-01, -2.60356098e-01,
#          1.94413945e-01, -9.90273580e-02, -6.99435830e-01,  1.22849584e-01,
#          3.60159725e-01,  3.33855987e-01,  0.00000000e+00, -2.72271466e-02,
#         -1.83713451e-01,  2.47735411e-01, -1.46248817e-01, -2.91003399e-02,
#         -5.75850680e-02,  2.56017804e+00,  2.57428037e-03, -3.51620987e-02,
#          8.42206031e-02, -5.98435700e-01,  5.42097725e-03,  6.01320207e-01,
#          2.79148436e+00, -4.89610225e-01,  3.38750243e-01,  1.03130829e+00,
#          9.78181839e-01, -2.34217584e-01,  1.07414198e+00, -1.14296424e+00,
#         -2.27386999e+00,  1.18945718e-01,  1.57954276e+00,  3.32549125e-01,
#          1.26378506e-01,  1.25656724e+00,  1.43345058e-01,  3.06833033e-02,
#         -3.08682173e-02,  1.05102646e+00,  4.26030278e-01, -1.04345761e-01,
#          1.10603899e-01,  4.60278183e-01,  1.48337650e+00,  1.24671176e-01,
#         -6.84215009e-01,  2.56828487e-01, -1.14692682e-02, -7.02609718e-01,
#          4.47716236e-01,  4.94696200e-02, -1.73162967e-01, -3.01975440e-02,
#          1.50380480e+00, -6.86379015e-01, -3.52252871e-01,  1.12603970e-01,
#          5.90476841e-02,  4.97158855e-01,  3.27809930e-01,  1.36411536e+00,
#          6.31489307e-02,  9.26396012e-01,  6.07448995e-01, -8.94820988e-02,
#         -2.98577070e-01, -4.35050987e-02, -7.34797955e-01,  3.53417486e-01,
#          7.47732162e-01, -7.34642446e-02, -7.70933256e-02,  2.05181882e-01,
#         -6.71069622e-01, -1.60823137e-01,  8.24652463e-02,  1.80484712e-01,
#          4.48041037e-02, -1.16957091e-01,  3.17617059e-02,  2.62294501e-01,
#         -3.63971852e-02,  3.92937750e-01,  2.54678309e-01, -9.46858823e-02,
#         -7.99260795e-01,  6.32282734e-01, -2.07412522e-02, -3.82729232e-01,
#         -1.46164727e+00,  2.46926475e+00,  0.00000000e+00, -4.13098127e-01,
#          4.93477955e-02,  1.47503126e+00,  2.21609220e-01, -2.03031339e-02,
#         -3.35930586e-01, -1.25529969e+00,  2.99832910e-01,  5.68796992e-02,
#         -5.97462542e-02,  1.21063933e-01, -6.96434528e-02, -2.01077297e-01,
#          1.67091608e+00, -2.11427122e-01,  3.37781012e-01,  1.50153446e+00,
#          3.94135267e-01,  2.55592018e-02, -1.88083038e-01,  7.75761008e-01,
#          8.57679486e-01, -2.50816438e-02,  4.52684075e-01, -1.29747063e-01,
#          1.62124857e-01,  3.69124871e-04, -8.70595813e-01, -4.13809299e-01,
#          5.88519514e-01, -2.77124941e-01, -6.66972518e-01, -5.24545312e-02,
#          4.54276621e-01, -1.89577863e-01, -1.01604104e+00, -7.04943478e-01,
#          6.26227319e-01, -1.23165749e-01,  4.85351384e-01, -3.76683846e-02,
#         -1.63530126e-01, -9.05521959e-02, -1.49247241e+00, -5.13327541e-03,
#         -2.72492379e-01,  6.56394586e-02, -4.43387032e-01, -1.56338468e-01,
#          3.43757963e+00,  1.02805585e-01,  3.73233020e-01,  5.40126324e-01,
#         -5.23370028e-01,  3.28177184e-01, -1.22646816e-01,  3.86030793e-01,
#         -4.27196652e-01,  6.29500207e-03, -3.17402154e-01,  6.66962415e-02,
#         -9.06248152e-01,  1.56976864e-01,  1.50670335e-01,  2.28169069e-01,
#         -5.35874963e-01,  2.98220497e-02,  3.02450769e-02, -2.47198358e-01,
#          2.19205052e-01,  2.35475495e-01, -1.47332832e-01, -6.70764148e-02,
#         -7.13564098e-01,  1.47258663e+00, -3.18158984e-01, -1.90546668e+00,
#         -3.09946895e-01,  1.29245055e+00,  1.05211711e+00, -3.54530327e-02,
#         -1.28966177e+00, -3.99379075e-01, -4.28422779e-01, -1.25738963e-01,
#         -1.53631938e+00, -1.42194778e-01, -3.96123707e-01,  6.86191693e-02,
#         -1.18718095e-01,  7.61750899e-03, -1.99549809e-01, -1.32455528e+00,
#          6.03381358e-02,  2.26172395e-02, -9.23790038e-02, -8.29869509e-01,
#         -1.80142176e+00, -4.11439806e-01, -9.14683104e-01,  5.87225735e-01,
#         -6.62660375e-02,  1.46385026e+00, -5.34192324e-02, -3.27872574e-01,
#          1.61669374e+00, -8.45271826e-01,  9.97536480e-01,  2.71780372e-01,
#          3.93557489e-01, -1.98986515e-01,  2.07272500e-01, -2.66779757e+00,
#          7.71120787e-02, -1.29633319e+00, -5.15611291e-01,  6.86368167e-01,
#         -1.69007376e-01,  1.52600384e+00, -4.06072050e-01, -9.17736366e-02,
#         -4.69728447e-02, -3.45194548e-01, -2.21715435e-01, -3.37179214e-01,
#         -1.58369851e+00, -1.56344086e-01, -2.38477692e-01, -7.29755461e-01,
#         -9.53365505e-01,  1.77837086e+00, -3.55455667e-01, -8.14217865e-01,
#         -7.34711215e-02,  5.00731766e-02,  9.33608592e-01,  4.23372924e-01,
#          9.48474929e-02,  7.76874125e-02, -8.93177986e-02,  4.37002987e-01,
#         -6.23375416e-01,  9.59948525e-02, -6.20049164e-02,  1.14562683e-01,
#          3.94894934e+00,  1.80026376e+00,  2.05473602e-01, -6.51926851e+00,
#          3.25558893e-02,  7.90065944e-01, -8.60117078e-01,  2.67348409e-01,
#         -2.19393089e-01, -3.55187535e-01, -1.59226000e-01, -1.17721654e-01,
#          4.52958256e-01, -1.42445207e-01, -6.05278909e-01, -2.01779399e-02,
#          9.08949971e-01,  1.53196907e+00, -1.23439260e-01, -8.20215195e-02,
#          1.16068244e+00,  3.78209502e-01, -3.28487068e-01,  2.80505085e+00,
#         -1.45679072e-01,  2.08667815e-02, -1.53863358e+00,  1.32826519e+00,
#          9.72053111e-02,  1.51797444e-01,  3.31902027e-01,  1.32735837e+00,
#         -8.93135443e-02,  1.87765133e+00,  8.47184286e-02,  1.91551316e+00,
#         -5.43321848e-01,  3.75146329e-01, -5.01655817e-01,  5.45525812e-02,
#         -2.40671560e-01,  5.02697766e-01,  7.37646073e-02], dtype=float32))

# %%
y_train.shape, X_train.shape
# Out:
# (torch.Size([1195]), torch.Size([1195, 18]))

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

def objective(trial):
    
    #define the search space
    n_estimators= trial.suggest_int("n_estimators", 100, 1000)
    max_depth = trial.suggest_int('max_depth', 5, 30)
    min_samples_split = trial.suggest_float('min_samples_split', 0.1, 1.0)
    min_samples_leaf = trial.suggest_float('min_samples_leaf', 0.1, 0.5)
    
    #create the model
    model = RandomForestRegressor(n_estimators,
                                 max_depth=max_depth,
                                 min_samples_split=min_samples_split,
                                 min_samples_leaf=min_samples_leaf,
                                 random_state=42)
    
    #training & testing loop
    model.fit(X_train, y_train)
    model_predictions = model.predict(X_test)
    
    #make predictions on data set
    mse = mean_squared_error(y_test, model_predictions)
    return mse


#Create an Optuna Study
study_3 = optuna.create_study(direction='minimize')

#Perform hyperparameter optimization
study_3.optimize(objective, n_trials=100)

#Print best spearman correlation coefficient
best_validation_metric = study_3.best_value
# Out:
# [I 2023-11-08 07:10:18,089] A new study created in memory with name: no-name-c96795f6-48c6-4108-9300-6d195490255d
# [I 2023-11-08 07:10:18,461] Trial 0 finished with value: 0.766444713967228 and parameters: {'n_estimators': 876, 'max_depth': 7, 'min_samples_split': 0.7474505613834166, 'min_samples_leaf': 0.27800876599230734}. Best is trial 0 with value: 0.766444713967228.
# [I 2023-11-08 07:10:18,674] Trial 1 finished with value: 0.7663947576396374 and parameters: {'n_estimators': 539, 'max_depth': 30, 'min_samples_split': 0.16564730785898213, 'min_samples_leaf': 0.3284254470655301}. Best is trial 1 with value: 0.7663947576396374.
# [I 2023-11-08 07:10:18,968] Trial 2 finished with value: 0.7413064114503799 and parameters: {'n_estimators': 211, 'max_depth': 14, 'min_samples_split': 0.465179543553217, 'min_samples_leaf': 0.1605275779823189}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:19,095] Trial 3 finished with value: 0.7664167687107659 and parameters: {'n_estimators': 321, 'max_depth': 16, 'min_samples_split': 0.16747510556489822, 'min_samples_leaf': 0.4826784739342136}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:19,201] Trial 4 finished with value: 0.7664021564597701 and parameters: {'n_estimators': 271, 'max_depth': 6, 'min_samples_split': 0.5877823189363802, 'min_samples_leaf': 0.4080321357984992}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:19,511] Trial 5 finished with value: 0.7664454186800457 and parameters: {'n_estimators': 788, 'max_depth': 12, 'min_samples_split': 0.862891805628561, 'min_samples_leaf': 0.23929958910201596}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:19,714] Trial 6 finished with value: 0.7664191739728611 and parameters: {'n_estimators': 516, 'max_depth': 29, 'min_samples_split': 0.4585744044932037, 'min_samples_leaf': 0.43799050765367237}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:20,911] Trial 7 finished with value: 0.7450784799721227 and parameters: {'n_estimators': 974, 'max_depth': 30, 'min_samples_split': 0.5526235076824549, 'min_samples_leaf': 0.16873043162876833}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:20,966] Trial 8 finished with value: 0.7664063164230819 and parameters: {'n_estimators': 138, 'max_depth': 7, 'min_samples_split': 0.22684145957229107, 'min_samples_leaf': 0.3580785479419182}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:21,106] Trial 9 finished with value: 0.7506795476500633 and parameters: {'n_estimators': 117, 'max_depth': 22, 'min_samples_split': 0.6161562510440272, 'min_samples_leaf': 0.19566743626045519}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:21,251] Trial 10 finished with value: 0.7664232012837848 and parameters: {'n_estimators': 351, 'max_depth': 21, 'min_samples_split': 0.9751714291197963, 'min_samples_leaf': 0.1080960103833575}. Best is trial 2 with value: 0.7413064114503799.
# [I 2023-11-08 07:10:22,770] Trial 11 finished with value: 0.7379490026798788 and parameters: {'n_estimators': 969, 'max_depth': 14, 'min_samples_split': 0.4224493901082223, 'min_samples_leaf': 0.15067166528369139}. Best is trial 11 with value: 0.7379490026798788.
# [I 2023-11-08 07:10:23,934] Trial 12 finished with value: 0.7300971782849915 and parameters: {'n_estimators': 649, 'max_depth': 14, 'min_samples_split': 0.3816815340517801, 'min_samples_leaf': 0.12040905546217068}. Best is trial 12 with value: 0.7300971782849915.
# [I 2023-11-08 07:10:25,320] Trial 13 finished with value: 0.7275823906190646 and parameters: {'n_estimators': 720, 'max_depth': 11, 'min_samples_split': 0.33746842069435923, 'min_samples_leaf': 0.11107549352466603}. Best is trial 13 with value: 0.7275823906190646.
# [I 2023-11-08 07:10:26,773] Trial 14 finished with value: 0.7244561442221519 and parameters: {'n_estimators': 708, 'max_depth': 10, 'min_samples_split': 0.31809137506502283, 'min_samples_leaf': 0.10112877430083744}. Best is trial 14 with value: 0.7244561442221519.
# [I 2023-11-08 07:10:27,627] Trial 15 finished with value: 0.753083448172438 and parameters: {'n_estimators': 711, 'max_depth': 10, 'min_samples_split': 0.30638948131292115, 'min_samples_leaf': 0.21842551752209477}. Best is trial 14 with value: 0.7244561442221519.
# [I 2023-11-08 07:10:28,954] Trial 16 finished with value: 0.7237752969128323 and parameters: {'n_estimators': 622, 'max_depth': 10, 'min_samples_split': 0.29391986507348644, 'min_samples_leaf': 0.10327031359921868}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:29,480] Trial 17 finished with value: 0.7546263152614427 and parameters: {'n_estimators': 442, 'max_depth': 20, 'min_samples_split': 0.2708109701441537, 'min_samples_leaf': 0.2541430006993026}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:30,337] Trial 18 finished with value: 0.7499304231260157 and parameters: {'n_estimators': 638, 'max_depth': 5, 'min_samples_split': 0.1076275236248595, 'min_samples_leaf': 0.1962609491306047}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:31,314] Trial 19 finished with value: 0.7551496221386148 and parameters: {'n_estimators': 848, 'max_depth': 9, 'min_samples_split': 0.2643677633209992, 'min_samples_leaf': 0.2855241997827915}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:32,150] Trial 20 finished with value: 0.7257606642026917 and parameters: {'n_estimators': 422, 'max_depth': 19, 'min_samples_split': 0.3636829738094117, 'min_samples_leaf': 0.1004783276313792}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:32,991] Trial 21 finished with value: 0.7258709897711821 and parameters: {'n_estimators': 428, 'max_depth': 25, 'min_samples_split': 0.35513346756904185, 'min_samples_leaf': 0.10178116360086874}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:33,993] Trial 22 finished with value: 0.7328644871361435 and parameters: {'n_estimators': 612, 'max_depth': 18, 'min_samples_split': 0.4780414904277931, 'min_samples_leaf': 0.13665579294114652}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:34,759] Trial 23 finished with value: 0.7364742315277131 and parameters: {'n_estimators': 459, 'max_depth': 17, 'min_samples_split': 0.3657906807091176, 'min_samples_leaf': 0.14629419138739513}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:35,634] Trial 24 finished with value: 0.745323292169679 and parameters: {'n_estimators': 585, 'max_depth': 24, 'min_samples_split': 0.2417236170926183, 'min_samples_leaf': 0.17758665049689593}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:37,010] Trial 25 finished with value: 0.7306912377311912 and parameters: {'n_estimators': 715, 'max_depth': 9, 'min_samples_split': 0.2988242086289602, 'min_samples_leaf': 0.140071415118263}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:37,727] Trial 26 finished with value: 0.7283843007977014 and parameters: {'n_estimators': 389, 'max_depth': 19, 'min_samples_split': 0.406741996519739, 'min_samples_leaf': 0.10972375725560124}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:38,348] Trial 27 finished with value: 0.7536965650048685 and parameters: {'n_estimators': 503, 'max_depth': 12, 'min_samples_split': 0.5171956917220567, 'min_samples_leaf': 0.21301280456697416}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:39,825] Trial 28 finished with value: 0.7309085704118806 and parameters: {'n_estimators': 798, 'max_depth': 16, 'min_samples_split': 0.3249691206950263, 'min_samples_leaf': 0.1332008772354844}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:40,200] Trial 29 finished with value: 0.761815129550155 and parameters: {'n_estimators': 673, 'max_depth': 8, 'min_samples_split': 0.6407577850440883, 'min_samples_leaf': 0.17757658883108485}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:41,934] Trial 30 finished with value: 0.7255561737692412 and parameters: {'n_estimators': 915, 'max_depth': 23, 'min_samples_split': 0.42494302729958444, 'min_samples_leaf': 0.10042850664775306}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:43,691] Trial 31 finished with value: 0.7263133745765352 and parameters: {'n_estimators': 906, 'max_depth': 26, 'min_samples_split': 0.407916741666195, 'min_samples_leaf': 0.10512619047053551}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:45,337] Trial 32 finished with value: 0.727912894109204 and parameters: {'n_estimators': 785, 'max_depth': 22, 'min_samples_split': 0.20493390093025352, 'min_samples_leaf': 0.12968332955265738}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:47,234] Trial 33 finished with value: 0.7241713923342452 and parameters: {'n_estimators': 898, 'max_depth': 23, 'min_samples_split': 0.30409934291501795, 'min_samples_leaf': 0.10061762105572797}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:48,770] Trial 34 finished with value: 0.739845256239029 and parameters: {'n_estimators': 903, 'max_depth': 27, 'min_samples_split': 0.19034980587243938, 'min_samples_leaf': 0.16178376941377895}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:50,502] Trial 35 finished with value: 0.728149341519988 and parameters: {'n_estimators': 843, 'max_depth': 23, 'min_samples_split': 0.26663149835704214, 'min_samples_leaf': 0.13238000703702785}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:52,158] Trial 36 finished with value: 0.7360505076147503 and parameters: {'n_estimators': 931, 'max_depth': 27, 'min_samples_split': 0.13130685097600134, 'min_samples_leaf': 0.1537009416761148}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:53,839] Trial 37 finished with value: 0.727229588246604 and parameters: {'n_estimators': 779, 'max_depth': 13, 'min_samples_split': 0.169176964691929, 'min_samples_leaf': 0.12471524492836644}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:55,267] Trial 38 finished with value: 0.7421034206277318 and parameters: {'n_estimators': 991, 'max_depth': 15, 'min_samples_split': 0.44448832679723205, 'min_samples_leaf': 0.16257530038689344}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:55,506] Trial 39 finished with value: 0.7658881103801496 and parameters: {'n_estimators': 558, 'max_depth': 24, 'min_samples_split': 0.30665355782392295, 'min_samples_leaf': 0.32449092060089746}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:57,351] Trial 40 finished with value: 0.727000594905128 and parameters: {'n_estimators': 841, 'max_depth': 7, 'min_samples_split': 0.22923123408802817, 'min_samples_leaf': 0.12433206569653056}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:57,840] Trial 41 finished with value: 0.7248844108211401 and parameters: {'n_estimators': 237, 'max_depth': 20, 'min_samples_split': 0.36722045631141403, 'min_samples_leaf': 0.10067898818411707}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:58,265] Trial 42 finished with value: 0.7350382010107069 and parameters: {'n_estimators': 273, 'max_depth': 21, 'min_samples_split': 0.4808703007218429, 'min_samples_leaf': 0.1454237034285049}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:58,632] Trial 43 finished with value: 0.7251880095450853 and parameters: {'n_estimators': 187, 'max_depth': 23, 'min_samples_split': 0.3883564115687005, 'min_samples_leaf': 0.10109021663742128}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:58,983] Trial 44 finished with value: 0.7314388065308512 and parameters: {'n_estimators': 190, 'max_depth': 20, 'min_samples_split': 0.38502477249234685, 'min_samples_leaf': 0.12695502855265348}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:10:59,252] Trial 45 finished with value: 0.7435435495968322 and parameters: {'n_estimators': 166, 'max_depth': 17, 'min_samples_split': 0.33451955871429645, 'min_samples_leaf': 0.17283871598242123}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:00,212] Trial 46 finished with value: 0.7348862874149539 and parameters: {'n_estimators': 505, 'max_depth': 28, 'min_samples_split': 0.28173493365946567, 'min_samples_leaf': 0.1493857509636427}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:00,772] Trial 47 finished with value: 0.7249903296900686 and parameters: {'n_estimators': 245, 'max_depth': 21, 'min_samples_split': 0.2311536793099615, 'min_samples_leaf': 0.1184005904235864}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:01,357] Trial 48 finished with value: 0.7256643327075903 and parameters: {'n_estimators': 257, 'max_depth': 11, 'min_samples_split': 0.20616185280890847, 'min_samples_leaf': 0.11920042931525615}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:02,066] Trial 49 finished with value: 0.7270628896205886 and parameters: {'n_estimators': 319, 'max_depth': 21, 'min_samples_split': 0.15174381774315238, 'min_samples_leaf': 0.12261517262354041}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:02,234] Trial 50 finished with value: 0.7470598241463826 and parameters: {'n_estimators': 108, 'max_depth': 19, 'min_samples_split': 0.24913658905184632, 'min_samples_leaf': 0.18698529948562026}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:02,714] Trial 51 finished with value: 0.7255806570657317 and parameters: {'n_estimators': 234, 'max_depth': 22, 'min_samples_split': 0.3241707877371475, 'min_samples_leaf': 0.10509176618462855}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:03,438] Trial 52 finished with value: 0.7269819486541609 and parameters: {'n_estimators': 332, 'max_depth': 25, 'min_samples_split': 0.29356447018443765, 'min_samples_leaf': 0.11717353944432181}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:03,740] Trial 53 finished with value: 0.7398913908703247 and parameters: {'n_estimators': 161, 'max_depth': 23, 'min_samples_split': 0.3584654119810671, 'min_samples_leaf': 0.15693245755342206}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:04,326] Trial 54 finished with value: 0.7280324664516854 and parameters: {'n_estimators': 289, 'max_depth': 18, 'min_samples_split': 0.23390710906634699, 'min_samples_leaf': 0.13815763670560063}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:04,717] Trial 55 finished with value: 0.7289894272049786 and parameters: {'n_estimators': 211, 'max_depth': 5, 'min_samples_split': 0.3880365168242455, 'min_samples_leaf': 0.11659766748325431}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:05,600] Trial 56 finished with value: 0.7239120983669295 and parameters: {'n_estimators': 386, 'max_depth': 20, 'min_samples_split': 0.26754952050161235, 'min_samples_leaf': 0.10144793280509089}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:06,953] Trial 57 finished with value: 0.7311692869277256 and parameters: {'n_estimators': 688, 'max_depth': 16, 'min_samples_split': 0.2610458532281569, 'min_samples_leaf': 0.14363922978865917}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:07,844] Trial 58 finished with value: 0.7254353115852717 and parameters: {'n_estimators': 386, 'max_depth': 20, 'min_samples_split': 0.18502921671904607, 'min_samples_leaf': 0.11577538577667056}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:09,044] Trial 59 finished with value: 0.7407721207914609 and parameters: {'n_estimators': 749, 'max_depth': 21, 'min_samples_split': 0.34028748915772045, 'min_samples_leaf': 0.1644108536585116}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:10,278] Trial 60 finished with value: 0.7304593001124332 and parameters: {'n_estimators': 630, 'max_depth': 15, 'min_samples_split': 0.2883677475035505, 'min_samples_leaf': 0.1408495596640729}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:10,776] Trial 61 finished with value: 0.7245814497983166 and parameters: {'n_estimators': 225, 'max_depth': 24, 'min_samples_split': 0.30597171155558056, 'min_samples_leaf': 0.10198071381137805}. Best is trial 16 with value: 0.7237752969128323.
# [I 2023-11-08 07:11:11,742] Trial 62 finished with value: 0.7219084667441553 and parameters: {'n_estimators': 368, 'max_depth': 25, 'min_samples_split': 0.21705024893728425, 'min_samples_leaf': 0.10006354411930522}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:12,739] Trial 63 finished with value: 0.7245143849580564 and parameters: {'n_estimators': 467, 'max_depth': 25, 'min_samples_split': 0.30568442016907776, 'min_samples_leaf': 0.10038423266328926}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:13,481] Trial 64 finished with value: 0.7280544425078445 and parameters: {'n_estimators': 374, 'max_depth': 26, 'min_samples_split': 0.31662959174669236, 'min_samples_leaf': 0.11399336568400802}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:14,475] Trial 65 finished with value: 0.7286711200551856 and parameters: {'n_estimators': 472, 'max_depth': 30, 'min_samples_split': 0.20442869058380764, 'min_samples_leaf': 0.12910148340870675}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:15,708] Trial 66 finished with value: 0.7238495386552225 and parameters: {'n_estimators': 547, 'max_depth': 25, 'min_samples_split': 0.2726384556672944, 'min_samples_leaf': 0.10042843065265707}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:16,707] Trial 67 finished with value: 0.7363035564031455 and parameters: {'n_estimators': 555, 'max_depth': 25, 'min_samples_split': 0.270624377963419, 'min_samples_leaf': 0.15311037043007392}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:17,921] Trial 68 finished with value: 0.7289523172954494 and parameters: {'n_estimators': 601, 'max_depth': 29, 'min_samples_split': 0.10384608471360832, 'min_samples_leaf': 0.13543676372850255}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:19,034] Trial 69 finished with value: 0.7244739217444368 and parameters: {'n_estimators': 478, 'max_depth': 26, 'min_samples_split': 0.15527156124449148, 'min_samples_leaf': 0.11338877595760363}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:19,889] Trial 70 finished with value: 0.7289356454073325 and parameters: {'n_estimators': 417, 'max_depth': 27, 'min_samples_split': 0.1475080953286429, 'min_samples_leaf': 0.13376930886815647}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:21,141] Trial 71 finished with value: 0.7247211237839856 and parameters: {'n_estimators': 531, 'max_depth': 26, 'min_samples_split': 0.21654617246618726, 'min_samples_leaf': 0.1113781153209171}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:22,283] Trial 72 finished with value: 0.724777321016374 and parameters: {'n_estimators': 484, 'max_depth': 25, 'min_samples_split': 0.17980725958897845, 'min_samples_leaf': 0.11196989993844467}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:23,283] Trial 73 finished with value: 0.7256319707189931 and parameters: {'n_estimators': 444, 'max_depth': 10, 'min_samples_split': 0.2500323136168153, 'min_samples_leaf': 0.11249400285863143}. Best is trial 62 with value: 0.7219084667441553.
# [I 2023-11-08 07:11:24,215] Trial 74 finished with value: 0.7214074424806814 and parameters: {'n_estimators': 364, 'max_depth': 28, 'min_samples_split': 0.13216427917075566, 'min_samples_leaf': 0.1002395644210297}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:24,984] Trial 75 finished with value: 0.7275339219935527 and parameters: {'n_estimators': 355, 'max_depth': 29, 'min_samples_split': 0.1394897244665767, 'min_samples_leaf': 0.12593660206091456}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:25,801] Trial 76 finished with value: 0.7311645027097259 and parameters: {'n_estimators': 415, 'max_depth': 28, 'min_samples_split': 0.16826905067236167, 'min_samples_leaf': 0.14169755791537858}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:27,025] Trial 77 finished with value: 0.7279564583680784 and parameters: {'n_estimators': 570, 'max_depth': 6, 'min_samples_split': 0.11818058370837115, 'min_samples_leaf': 0.12591686384524975}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:28,105] Trial 78 finished with value: 0.7368024854779194 and parameters: {'n_estimators': 608, 'max_depth': 24, 'min_samples_split': 0.1554176674749501, 'min_samples_leaf': 0.15442405105069895}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:29,373] Trial 79 finished with value: 0.7239084018596339 and parameters: {'n_estimators': 532, 'max_depth': 27, 'min_samples_split': 0.19130818491378251, 'min_samples_leaf': 0.11020146689547318}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:31,100] Trial 80 finished with value: 0.7215978766318392 and parameters: {'n_estimators': 661, 'max_depth': 28, 'min_samples_split': 0.19624487097799906, 'min_samples_leaf': 0.10068662953920107}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:32,717] Trial 81 finished with value: 0.7230402402561352 and parameters: {'n_estimators': 660, 'max_depth': 28, 'min_samples_split': 0.196341897108417, 'min_samples_leaf': 0.10858202436288927}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:34,234] Trial 82 finished with value: 0.7233721068997233 and parameters: {'n_estimators': 637, 'max_depth': 28, 'min_samples_split': 0.1921845136419457, 'min_samples_leaf': 0.110347086139932}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:35,989] Trial 83 finished with value: 0.7230187365323849 and parameters: {'n_estimators': 679, 'max_depth': 28, 'min_samples_split': 0.19729075673467422, 'min_samples_leaf': 0.110427263772569}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:37,296] Trial 84 finished with value: 0.7286542440354211 and parameters: {'n_estimators': 639, 'max_depth': 28, 'min_samples_split': 0.1956039415133469, 'min_samples_leaf': 0.1345414586091983}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:38,825] Trial 85 finished with value: 0.7267124078525572 and parameters: {'n_estimators': 670, 'max_depth': 30, 'min_samples_split': 0.1272264974848439, 'min_samples_leaf': 0.12208804351461398}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:40,612] Trial 86 finished with value: 0.7230587860010754 and parameters: {'n_estimators': 746, 'max_depth': 29, 'min_samples_split': 0.18056461196216486, 'min_samples_leaf': 0.10924001399354853}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:41,824] Trial 87 finished with value: 0.7408903076911113 and parameters: {'n_estimators': 745, 'max_depth': 29, 'min_samples_split': 0.21590803590968086, 'min_samples_leaf': 0.16597910291470325}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:43,079] Trial 88 finished with value: 0.733783342232833 and parameters: {'n_estimators': 665, 'max_depth': 28, 'min_samples_split': 0.10687605279947089, 'min_samples_leaf': 0.14885569260360038}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:44,605] Trial 89 finished with value: 0.7271625873831241 and parameters: {'n_estimators': 693, 'max_depth': 29, 'min_samples_split': 0.22485608683736705, 'min_samples_leaf': 0.12453896524948911}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:46,190] Trial 90 finished with value: 0.7278305741146175 and parameters: {'n_estimators': 720, 'max_depth': 30, 'min_samples_split': 0.17116392300301042, 'min_samples_leaf': 0.12849046236305406}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:47,591] Trial 91 finished with value: 0.7233431699129723 and parameters: {'n_estimators': 526, 'max_depth': 28, 'min_samples_split': 0.1950929145099641, 'min_samples_leaf': 0.10737599127697872}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:49,013] Trial 92 finished with value: 0.7257548825058562 and parameters: {'n_estimators': 579, 'max_depth': 27, 'min_samples_split': 0.24433383114395443, 'min_samples_leaf': 0.11389699216445373}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:50,614] Trial 93 finished with value: 0.7230291902338629 and parameters: {'n_estimators': 625, 'max_depth': 28, 'min_samples_split': 0.13365003306047535, 'min_samples_leaf': 0.10801634381884159}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:52,428] Trial 94 finished with value: 0.7239505188139008 and parameters: {'n_estimators': 742, 'max_depth': 28, 'min_samples_split': 0.12662498235659214, 'min_samples_leaf': 0.1116996037614902}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:53,742] Trial 95 finished with value: 0.7294305580262758 and parameters: {'n_estimators': 624, 'max_depth': 29, 'min_samples_split': 0.17873756229953214, 'min_samples_leaf': 0.13877711640795581}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:55,629] Trial 96 finished with value: 0.7261469900435892 and parameters: {'n_estimators': 815, 'max_depth': 27, 'min_samples_split': 0.14654921429622858, 'min_samples_leaf': 0.11980221170519308}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:56,979] Trial 97 finished with value: 0.7321070549135184 and parameters: {'n_estimators': 652, 'max_depth': 30, 'min_samples_split': 0.1691021336854659, 'min_samples_leaf': 0.14485407808023323}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:11:58,611] Trial 98 finished with value: 0.7228344081179878 and parameters: {'n_estimators': 597, 'max_depth': 28, 'min_samples_split': 0.20281792684905325, 'min_samples_leaf': 0.10783148937903403}. Best is trial 74 with value: 0.7214074424806814.
# [I 2023-11-08 07:12:00,066] Trial 99 finished with value: 0.7229786532481919 and parameters: {'n_estimators': 593, 'max_depth': 28, 'min_samples_split': 0.2072603972631124, 'min_samples_leaf': 0.1077986131231722}. Best is trial 74 with value: 0.7214074424806814.
